# %%
from sklearn.externals.joblib import Memory
from sklearn.datasets import load_svmlight_file
from sklearn import datasets
from sklearn import model_selection
import numpy as np
import matplotlib as mp
import jupyter
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mem = Memory("./mycache")

@mem.cache
def get_data(mysvmlightfile):
    data = load_svmlight_file(mysvmlightfile)
    return data[0], data[1]

# %%
#读取数据集
x_data,y_data=datasets.load_svmlight_file('australian_scale.txt')

# %%
x_data=x_data.todense()
one=np.ones(x_data.shape[0])
x_data=np.column_stack((x_data,one))

# %%
#划分训练集和测试集，20%的数据作为测试集
x_train,x_test,y_train,y_test=model_selection.train_test_split(x_data,y_data,train_size=0.8,test_size=0.2,random_state=0)

# %%
#调整数据维度
y_data=np.mat(y_data).T
y_train=np.mat(y_train).T
y_test=np.mat(y_test).T

# %%
#参数全零初始化
w=np.zeros(x_train.shape[1])
w=np.mat(w)
w=w.T

#学习速率
rate=0.0005
#C
c=0.1

# %%
#输出数据维度
print(x_data.shape,y_data.shape,w.shape,)
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (690, 15) (690, 1) (15, 1)
# (552, 15) (552, 1)
# (138, 15) (138, 1)

# %%
#存储循环次数，L_train,L_validation数组来画图
epoch_array=[]
L_train_array=[]
L_validation_array=[]

# %%
#循环次数
epoch=0

# %% [markdown]
# 选用svm线性模型yi=w.T*xi+b,loss function=1/2 * w.T * w + c*max(0,1-yi*(w.T*xi+b))。
# 对w求梯度:当1-yi*(w.T*xi+b)>=0时，grad_w = w-c*(yi*xi).T,
# 当1-yi*(w.T*xi+b)< 0时,grad_w=w.
# 对b求梯度，当1-yi*(w.T*xi+b)>=0时，grad_b = -c*yi,
# 当1-yi*(w.T*xi+b)< 0时,grad_b=0.
#
# 将b移入w矩阵，x数据增加一列全为1

# %%
while epoch<100:
    epoch =epoch + 1
    grad_w =0
    
    L_train =0
    L_test =0
    
    #计算grad_W
    for i in range(x_train.shape[0]):
        if(1-(y_train[i]*(x_train[i]*w))>0):
            grad_w=grad_w+w-c*(y_train[i]*x_train[i]).T
        else:
            grad_w=grad_w+w
            
    #更新 w
    w=w-rate*grad_w
    
    #计算L_train,L_validation
    for i in range(x_train.shape[0]):
        if(1-y_train[i]*(x_train[i]*w)>0):
            L_train=L_train+1-(y_train[i]*(x_train[i]*w))
    for i in range(x_test.shape[0]):
        if(1-y_test[i]*(x_test[i]*w)>0):
            L_test=L_test+(1-y_test[i]*(x_test[i]*w))
    L_train=0.5*w.T*w+c*L_train
    L_train=L_train/x_train.shape[0]
    L_test=0.5*w.T*w+c*L_test
    L_test=L_test/x_test.shape[0]
    
    #输出每一次迭代的loss值
    print("epoch:",epoch)
    print("train_error:",L_train)
    print("validation error:",L_test)
    
    #将数据存到数组中
    epoch_array.append(epoch)
    L_train_array.append(np.array(L_train)[0][0])
    L_validation_array.append(np.array(L_test)[0][0])
# Out:
# epoch: 1
# train_error: [[ 0.09744206]]
# validation error: [[ 0.09749134]]
# epoch: 2
# train_error: [[ 0.09559091]]
# validation error: [[ 0.09567826]]
# epoch: 3
# train_error: [[ 0.09425109]]
# validation error: [[ 0.09436727]]
# epoch: 4
# train_error: [[ 0.09328129]]
# validation error: [[ 0.09341899]]
# epoch: 5
# train_error: [[ 0.09257926]]
# validation error: [[ 0.09273289]]
# epoch: 6
# train_error: [[ 0.09207106]]
# validation error: [[ 0.0922364]]
# epoch: 7
# train_error: [[ 0.09170315]]
# validation error: [[ 0.09187707]]
# epoch: 8
# train_error: [[ 0.0914368]]
# validation error: [[ 0.09161698]]
# epoch: 9
# train_error: [[ 0.09124397]]
# validation error: [[ 0.0914287]]
# epoch: 10
# train_error: [[ 0.09110437]]
# validation error: [[ 0.09129241]]
# epoch: 11
# train_error: [[ 0.0910033]]
# validation error: [[ 0.09119375]]
# epoch: 12
# train_error: [[ 0.09093012]]
# validation error: [[ 0.09112232]]
# epoch: 13
# train_error: [[ 0.09087714]]
# validation error: [[ 0.09107061]]
# epoch: 14
# train_error: [[ 0.09083879]]
# validation error: [[ 0.09103317]]
# epoch: 15
# train_error: [[ 0.09081102]]
# validation error: [[ 0.09100607]]
# epoch: 16
# train_error: [[ 0.09079092]]
# validation error: [[ 0.09098644]]
# epoch: 17
# train_error: [[ 0.09077636]]
# validation error: [[ 0.09097224]]
# epoch: 18
# train_error: [[ 0.09076582]]
# validation error: [[ 0.09096195]]
# epoch: 19
# train_error: [[ 0.09075819]]
# validation error: [[ 0.09095451]]
# epoch: 20
# train_error: [[ 0.09075267]]
# validation error: [[ 0.09094911]]
# epoch: 21
# train_error: [[ 0.09074867]]
# validation error: [[ 0.09094521]]
# epoch: 22
# train_error: [[ 0.09074577]]
# validation error: [[ 0.09094238]]
# epoch: 23
# train_error: [[ 0.09074368]]
# validation error: [[ 0.09094034]]
# epoch: 24
# train_error: [[ 0.09074216]]
# validation error: [[ 0.09093886]]
# epoch: 25
# train_error: [[ 0.09074106]]
# validation error: [[ 0.09093778]]
# epoch: 26
# train_error: [[ 0.09074027]]
# validation error: [[ 0.09093701]]
# epoch: 27
# train_error: [[ 0.09073969]]
# validation error: [[ 0.09093645]]
# epoch: 28
# train_error: [[ 0.09073927]]
# validation error: [[ 0.09093604]]
# epoch: 29
# train_error: [[ 0.09073897]]
# validation error: [[ 0.09093574]]
# epoch: 30
# train_error: [[ 0.09073875]]
# validation error: [[ 0.09093553]]
# epoch: 31
# train_error: [[ 0.09073859]]
# validation error: [[ 0.09093538]]
# epoch: 32
# train_error: [[ 0.09073848]]
# validation error: [[ 0.09093526]]
# epoch: 33
# train_error: [[ 0.0907384]]
# validation error: [[ 0.09093518]]
# epoch: 34
# train_error: [[ 0.09073834]]
# validation error: [[ 0.09093513]]
# epoch: 35
# train_error: [[ 0.09073829]]
# validation error: [[ 0.09093508]]
# epoch: 36
# train_error: [[ 0.09073826]]
# validation error: [[ 0.09093505]]
# epoch: 37
# train_error: [[ 0.09073824]]
# validation error: [[ 0.09093503]]
# epoch: 38
# train_error: [[ 0.09073822]]
# validation error: [[ 0.09093501]]
# epoch: 39
# train_error: [[ 0.09073821]]
# validation error: [[ 0.090935]]
# epoch: 40
# train_error: [[ 0.0907382]]
# validation error: [[ 0.09093499]]
# epoch: 41
# train_error: [[ 0.09073819]]
# validation error: [[ 0.09093499]]
# epoch: 42
# train_error: [[ 0.09073819]]
# validation error: [[ 0.09093498]]
# epoch: 43
# train_error: [[ 0.09073819]]
# validation error: [[ 0.09093498]]
# epoch: 44
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093498]]
# epoch: 45
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093498]]
# epoch: 46
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 47
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 48
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 49
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 50
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 51
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 52
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 53
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 54
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 55
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 56
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 57
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 58
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 59
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 60
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 61
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 62
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 63
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 64
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 65
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 66
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 67
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 68
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 69
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 70
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 71
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 72
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 73
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 74
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 75
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 76
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 77
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 78
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 79
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 80
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 81
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 82
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 83
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 84
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 85
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 86
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 87
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 88
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 89
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 90
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 91
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 92
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 93
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 94
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 95
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 96
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 97
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 98
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 99
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]
# epoch: 100
# train_error: [[ 0.09073818]]
# validation error: [[ 0.09093497]]

# %%
#画图
plt.xlabel('epoch')
plt.ylabel('loss')
line1=plt.plot(epoch_array,L_train_array)
line2=plt.plot(epoch_array,L_validation_array)
label = ["L_train", "L_validation"]
plt.legend(label, loc = 0, ncol = 2)
plt.show()
